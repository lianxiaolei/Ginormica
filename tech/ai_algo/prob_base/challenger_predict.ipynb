# %%
import pymc as pm
import numpy as np
from matplotlib import pyplot as plt
from IPython.core.pylabtools import figsize
% matplotlib inline

# %%
import os
os.path.abspath(os.curdir)
# Out:
# '/home/lian19931201/ginormica/tech/ai_algo/prob_base'

# %%
def logistic(x, b, a):
    return 1.0 / (1 + np.exp(b * x + a))

# %%
figsize(12.5, 3.5)
challenger_data = np.genfromtxt('data/challenger_data.csv', skip_header=1, usecols=[1, 2], 
                                missing_values='NA', delimiter=',')
# drop the NA values
challenger_data = challenger_data[~np.isnan(challenger_data[:, 1])]
# plot it, as a function of temperature (the first column)
print("Temp (F), O-Ring failure?")
print(challenger_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-1aeca7dd105a> in <module>()
#       1 figsize(12.5, 3.5)
#       2 challenger_data = np.genfromtxt('data/challenger_data.csv', skip_header=1, usecols=[1, 2],
# ----> 3                                 missing_values='NA', delimiter=',')
#       4 # drop the NA values
#       5 challenger_data = challenger_data[~np.isnan(challenger_data[:, 1])]
#
# /home/lian19931201/anaconda2/lib/python2.7/site-packages/numpy/lib/npyio.pyc in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows)
#    1865             # Raise an exception ?
#    1866             if invalid_raise:
# -> 1867                 raise ValueError(errmsg)
#    1868             # Issue a warning ?
#    1869             else:
#
# ValueError: Some errors were detected !
#     Line #2 (got 1 columns instead of 2)
#     Line #3 (got 1 columns instead of 2)
#     Line #4 (got 1 columns instead of 2)
#     Line #5 (got 1 columns instead of 2)
#     Line #6 (got 1 columns instead of 2)
#     Line #7 (got 1 columns instead of 2)
#     Line #8 (got 2 columns instead of 2)
#     Line #9 (got 2 columns instead of 2)
#     Line #10 (got 1 columns instead of 2)
#     Line #11 (got 1 columns instead of 2)
#     Line #12 (got 1 columns instead of 2)
#     Line #13 (got 2 columns instead of 2)
#     Line #14 (got 1 columns instead of 2)
#     Line #15 (got 1 columns instead of 2)
#     Line #16 (got 1 columns instead of 2)
#     Line #17 (got 1 columns instead of 2)
#     Line #18 (got 1 columns instead of 2)
#     Line #19 (got 1 columns instead of 2)
#     Line #20 (got 1 columns instead of 2)
#     Line #21 (got 1 columns instead of 2)
#     Line #23 (got 1 columns instead of 2)
#     Line #30 (got 1 columns instead of 2)
#     Line #31 (got 1 columns instead of 2)
#     Line #32 (got 1 columns instead of 2)
#     Line #33 (got 1 columns instead of 2)
#     Line #34 (got 1 columns instead of 2)
#     Line #35 (got 1 columns instead of 2)
#     Line #36 (got 1 columns instead of 2)
#     Line #37 (got 1 columns instead of 2)
#     Line #38 (got 1 columns instead of 2)
#     Line #39 (got 1 columns instead of 2)
#     Line #40 (got 1 columns instead of 2)
#     Line #44 (got 1 columns instead of 2)
#     Line #45 (got 1 columns instead of 2)
#     Line #48 (got 1 columns instead of 2)
#     Line #51 (got 1 columns instead of 2)
#     Line #53 (got 1 columns instead of 2)
#     Line #54 (got 1 columns instead of 2)
#     Line #55 (got 1 columns instead of 2)
#     Line #56 (got 1 columns instead of 2)
#     Line #59 (got 2 columns instead of 2)
#     Line #61 (got 1 columns instead of 2)
#     Line #62 (got 1 columns instead of 2)
#     Line #63 (got 1 columns instead of 2)
#     Line #65 (got 1 columns instead of 2)
#     Line #67 (got 1 columns instead of 2)
#     Line #70 (got 1 columns instead of 2)
#     Line #72 (got 1 columns instead of 2)
#     Line #73 (got 1 columns instead of 2)
#     Line #74 (got 1 columns instead of 2)
#     Line #75 (got 1 columns instead of 2)
#     Line #77 (got 1 columns instead of 2)
#     Line #78 (got 1 columns instead of 2)
#     Line #79 (got 1 columns instead of 2)
#     Line #84 (got 1 columns instead of 2)
#     Line #89 (got 1 columns instead of 2)
#     Line #90 (got 1 columns instead of 2)
#     Line #92 (got 1 columns instead of 2)
#     Line #93 (got 1 columns instead of 2)
#     Line #97 (got 1 columns instead of 2)
#     Line #99 (got 1 columns instead of 2)
#     Line #102 (got 1 columns instead of 2)
#     Line #104 (got 2 columns instead of 2)
#     Line #105 (got 1 columns instead of 2)
#     Line #107 (got 1 columns instead of 2)
#     Line #110 (got 1 columns instead of 2)
#     Line #113 (got 1 columns instead of 2)
#     Line #115 (got 1 columns instead of 2)
#     Line #117 (got 1 columns instead of 2)
#     Line #118 (got 1 columns instead of 2)
#     Line #120 (got 1 columns instead of 2)
#     Line #124 (got 1 columns instead of 2)
#     Line #126 (got 1 columns instead of 2)
#     Line #128 (got 1 columns instead of 2)
#     Line #131 (got 1 columns instead of 2)
#     Line #132 (got 1 columns instead of 2)
#     Line #133 (got 1 columns instead of 2)
#     Line #137 (got 1 columns instead of 2)
#     Line #138 (got 1 columns instead of 2)
#     Line #139 (got 1 columns instead of 2)
#     Line #140 (got 1 columns instead of 2)
#     Line #141 (got 1 columns instead of 2)
#     Line #143 (got 1 columns instead of 2)
#     Line #145 (got 2 columns instead of 2)
#     Line #146 (got 1 columns instead of 2)
#     Line #147 (got 1 columns instead of 2)
#     Line #152 (got 1 columns instead of 2)
#     Line #153 (got 1 columns instead of 2)
#     Line #154 (got 1 columns instead of 2)
#     Line #156 (got 1 columns instead of 2)
#     Line #157 (got 1 columns instead of 2)
#     Line #159 (got 1 columns instead of 2)
#     Line #161 (got 1 columns instead of 2)
#     Line #162 (got 1 columns instead of 2)
#     Line #163 (got 1 columns instead of 2)
#     Line #164 (got 1 columns instead of 2)
#     Line #166 (got 1 columns instead of 2)
#     Line #167 (got 1 columns instead of 2)
#     Line #168 (got 1 columns instead of 2)
#     Line #170 (got 1 columns instead of 2)
#     Line #171 (got 1 columns instead of 2)
#     Line #173 (got 1 columns instead of 2)
#     Line #175 (got 1 columns instead of 2)
#     Line #176 (got 1 columns instead of 2)
#     Line #178 (got 1 columns instead of 2)
#     Line #180 (got 1 columns instead of 2)
#     Line #181 (got 1 columns instead of 2)
#     Line #182 (got 1 columns instead of 2)
#     Line #184 (got 1 columns instead of 2)
#     Line #185 (got 1 columns instead of 2)
#     Line #186 (got 1 columns instead of 2)
#     Line #187 (got 1 columns instead of 2)
#     Line #189 (got 1 columns instead of 2)
#     Line #190 (got 1 columns instead of 2)
#     Line #191 (got 1 columns instead of 2)
#     Line #192 (got 1 columns instead of 2)
#     Line #193 (got 1 columns instead of 2)
#     Line #194 (got 1 columns instead of 2)
#     Line #195 (got 1 columns instead of 2)
#     Line #196 (got 1 columns instead of 2)
#     Line #197 (got 1 columns instead of 2)
#     Line #198 (got 1 columns instead of 2)
#     Line #199 (got 1 columns instead of 2)
#     Line #200 (got 1 columns instead of 2)
#     Line #201 (got 1 columns instead of 2)
#     Line #202 (got 1 columns instead of 2)
#     Line #203 (got 1 columns instead of 2)
#     Line #204 (got 1 columns instead of 2)
#     Line #205 (got 1 columns instead of 2)
#     Line #206 (got 1 columns instead of 2)
#     Line #207 (got 1 columns instead of 2)
#     Line #209 (got 1 columns instead of 2)
#     Line #211 (got 1 columns instead of 2)
#     Line #212 (got 1 columns instead of 2)
#     Line #214 (got 1 columns instead of 2)
#     Line #216 (got 1 columns instead of 2)
#     Line #217 (got 1 columns instead of 2)
#     Line #218 (got 1 columns instead of 2)
#     Line #219 (got 1 columns instead of 2)
#     Line #220 (got 1 columns instead of 2)
#     Line #221 (got 1 columns instead of 2)
#     Line #223 (got 1 columns instead of 2)
#     Line #225 (got 1 columns instead of 2)
#     Line #227 (got 1 columns instead of 2)
#     Line #228 (got 1 columns instead of 2)
#     Line #232 (got 1 columns instead of 2)
#     Line #233 (got 1 columns instead of 2)
#     Line #234 (got 1 columns instead of 2)
#     Line #243 (got 1 columns instead of 2)
#     Line #244 (got 1 columns instead of 2)
#     Line #246 (got 1 columns instead of 2)
#     Line #247 (got 1 columns instead of 2)
#     Line #248 (got 1 columns instead of 2)
#     Line #249 (got 1 columns instead of 2)
#     Line #250 (got 1 columns instead of 2)
#     Line #251 (got 1 columns instead of 2)
#     Line #252 (got 1 columns instead of 2)
#     Line #253 (got 1 columns instead of 2)
#     Line #254 (got 1 columns instead of 2)
#     Line #255 (got 1 columns instead of 2)
#     Line #256 (got 1 columns instead of 2)
#     Line #257 (got 1 columns instead of 2)
#     Line #259 (got 1 columns instead of 2)
#     Line #261 (got 1 columns instead of 2)
#     Line #262 (got 1 columns instead of 2)
#     Line #263 (got 1 columns instead of 2)
#     Line #264 (got 1 columns instead of 2)
#     Line #265 (got 1 columns instead of 2)
#     Line #266 (got 1 columns instead of 2)
#     Line #267 (got 1 columns instead of 2)
#     Line #269 (got 1 columns instead of 2)
#     Line #270 (got 1 columns instead of 2)
#     Line #271 (got 1 columns instead of 2)
#     Line #272 (got 1 columns instead of 2)
#     Line #274 (got 1 columns instead of 2)
#     Line #276 (got 1 columns instead of 2)
#     Line #277 (got 1 columns instead of 2)
#     Line #278 (got 1 columns instead of 2)
#     Line #279 (got 1 columns instead of 2)
#     Line #280 (got 1 columns instead of 2)
#     Line #281 (got 1 columns instead of 2)
#     Line #282 (got 1 columns instead of 2)
#     Line #284 (got 1 columns instead of 2)
#     Line #285 (got 1 columns instead of 2)
#     Line #286 (got 1 columns instead of 2)
#     Line #287 (got 1 columns instead of 2)
#     Line #288 (got 1 columns instead of 2)
#     Line #289 (got 1 columns instead of 2)
#     Line #291 (got 1 columns instead of 2)
#     Line #292 (got 1 columns instead of 2)
#     Line #293 (got 1 columns instead of 2)
#     Line #294 (got 1 columns instead of 2)
#     Line #295 (got 1 columns instead of 2)
#     Line #297 (got 1 columns instead of 2)
#     Line #299 (got 1 columns instead of 2)
#     Line #301 (got 1 columns instead of 2)
#     Line #302 (got 1 columns instead of 2)
#     Line #303 (got 1 columns instead of 2)
#     Line #304 (got 1 columns instead of 2)
#     Line #305 (got 1 columns instead of 2)
#     Line #307 (got 1 columns instead of 2)
#     Line #308 (got 1 columns instead of 2)
#     Line #309 (got 1 columns instead of 2)
#     Line #310 (got 1 columns instead of 2)
#     Line #311 (got 1 columns instead of 2)
#     Line #312 (got 1 columns instead of 2)
#     Line #314 (got 1 columns instead of 2)
#     Line #315 (got 1 columns instead of 2)
#     Line #316 (got 1 columns instead of 2)
#     Line #317 (got 1 columns instead of 2)
#     Line #318 (got 1 columns instead of 2)
#     Line #319 (got 1 columns instead of 2)
#     Line #320 (got 1 columns instead of 2)
#     Line #322 (got 1 columns instead of 2)
#     Line #323 (got 1 columns instead of 2)
#     Line #324 (got 1 columns instead of 2)
#     Line #325 (got 1 columns instead of 2)
#     Line #326 (got 1 columns instead of 2)
#     Line #327 (got 1 columns instead of 2)
#     Line #328 (got 1 columns instead of 2)
#     Line #329 (got 1 columns instead of 2)
#     Line #330 (got 1 columns instead of 2)
#     Line #332 (got 1 columns instead of 2)
#     Line #333 (got 1 columns instead of 2)
#     Line #334 (got 1 columns instead of 2)
#     Line #335 (got 1 columns instead of 2)
#     Line #336 (got 1 columns instead of 2)
#     Line #339 (got 1 columns instead of 2)
#     Line #340 (got 1 columns instead of 2)
#     Line #341 (got 1 columns instead of 2)
#     Line #342 (got 1 columns instead of 2)
#     Line #344 (got 1 columns instead of 2)
#     Line #347 (got 1 columns instead of 2)
#     Line #349 (got 1 columns instead of 2)
#     Line #350 (got 1 columns instead of 2)
#     Line #353 (got 1 columns instead of 2)
#     Line #355 (got 1 columns instead of 2)
#     Line #357 (got 1 columns instead of 2)
#     Line #359 (got 1 columns instead of 2)
#     Line #360 (got 1 columns instead of 2)
#     Line #362 (got 1 columns instead of 2)
#     Line #363 (got 1 columns instead of 2)
#     Line #364 (got 1 columns instead of 2)
#     Line #365 (got 1 columns instead of 2)
#     Line #367 (got 1 columns instead of 2)
#     Line #369 (got 1 columns instead of 2)
#     Line #370 (got 1 columns instead of 2)
#     Line #371 (got 1 columns instead of 2)
#     Line #372 (got 1 columns instead of 2)
#     Line #373 (got 1 columns instead of 2)
#     Line #375 (got 1 columns instead of 2)
#     Line #376 (got 1 columns instead of 2)
#     Line #377 (got 1 columns instead of 2)
#     Line #378 (got 1 columns instead of 2)
#     Line #379 (got 1 columns instead of 2)
#     Line #380 (got 1 columns instead of 2)
#     Line #381 (got 1 columns instead of 2)
#     Line #382 (got 1 columns instead of 2)
#     Line #383 (got 1 columns instead of 2)
#     Line #384 (got 1 columns instead of 2)
#     Line #385 (got 1 columns instead of 2)
#     Line #386 (got 1 columns instead of 2)
#     Line #387 (got 1 columns instead of 2)
#     Line #388 (got 1 columns instead of 2)
#     Line #389 (got 1 columns instead of 2)
#     Line #391 (got 1 columns instead of 2)
#     Line #393 (got 1 columns instead of 2)
#     Line #396 (got 1 columns instead of 2)
#     Line #397 (got 1 columns instead of 2)
#     Line #398 (got 1 columns instead of 2)
#     Line #399 (got 1 columns instead of 2)
#     Line #400 (got 1 columns instead of 2)
#     Line #401 (got 1 columns instead of 2)
#     Line #402 (got 1 columns instead of 2)
#     Line #403 (got 1 columns instead of 2)
#     Line #404 (got 1 columns instead of 2)
#     Line #405 (got 1 columns instead of 2)
#     Line #406 (got 1 columns instead of 2)
#     Line #408 (got 1 columns instead of 2)
#     Line #409 (got 1 columns instead of 2)
#     Line #411 (got 1 columns instead of 2)
#     Line #412 (got 1 columns instead of 2)
#     Line #415 (got 1 columns instead of 2)
#     Line #417 (got 1 columns instead of 2)
#     Line #418 (got 1 columns instead of 2)
#     Line #420 (got 1 columns instead of 2)
#     Line #421 (got 1 columns instead of 2)
#     Line #422 (got 1 columns instead of 2)
#     Line #424 (got 1 columns instead of 2)
#     Line #425 (got 1 columns instead of 2)
#     Line #426 (got 1 columns instead of 2)
#     Line #427 (got 1 columns instead of 2)
#     Line #428 (got 1 columns instead of 2)
#     Line #429 (got 1 columns instead of 2)
#     Line #430 (got 1 columns instead of 2)
#     Line #431 (got 1 columns instead of 2)
#     Line #432 (got 1 columns instead of 2)
#     Line #433 (got 1 columns instead of 2)
#     Line #434 (got 1 columns instead of 2)
#     Line #435 (got 1 columns instead of 2)
#     Line #436 (got 1 columns instead of 2)
#     Line #437 (got 1 columns instead of 2)
#     Line #438 (got 1 columns instead of 2)
#     Line #439 (got 1 columns instead of 2)
#     Line #440 (got 1 columns instead of 2)
#     Line #441 (got 1 columns instead of 2)
#     Line #442 (got 1 columns instead of 2)
#     Line #443 (got 1 columns instead of 2)
#     Line #447 (got 1 columns instead of 2)
#     Line #448 (got 1 columns instead of 2)
#     Line #449 (got 1 columns instead of 2)
#     Line #450 (got 1 columns instead of 2)
#     Line #451 (got 1 columns instead of 2)
#     Line #452 (got 2 columns instead of 2)
#     Line #453 (got 1 columns instead of 2)
#     Line #454 (got 1 columns instead of 2)
#     Line #455 (got 1 columns instead of 2)
#     Line #456 (got 1 columns instead of 2)
#     Line #457 (got 1 columns instead of 2)
#     Line #458 (got 1 columns instead of 2)
#     Line #460 (got 1 columns instead of 2)
#     Line #461 (got 1 columns instead of 2)
#     Line #462 (got 1 columns instead of 2)
#     Line #463 (got 1 columns instead of 2)
#     Line #464 (got 1 columns instead of 2)
#     Line #466 (got 1 columns instead of 2)
#     Line #468 (got 1 columns instead of 2)
#     Line #469 (got 1 columns instead of 2)
#     Line #470 (got 1 columns instead of 2)
#     Line #471 (got 1 columns instead of 2)
#     Line #472 (got 1 columns instead of 2)
#     Line #473 (got 1 columns instead of 2)
#     Line #476 (got 1 columns instead of 2)
#     Line #477 (got 1 columns instead of 2)
#     Line #478 (got 1 columns instead of 2)
#     Line #480 (got 1 columns instead of 2)
#     Line #481 (got 1 columns instead of 2)
#     Line #482 (got 1 columns instead of 2)
#     Line #483 (got 1 columns instead of 2)
#     Line #484 (got 1 columns instead of 2)
#     Line #486 (got 1 columns instead of 2)
#     Line #487 (got 1 columns instead of 2)
#     Line #488 (got 1 columns instead of 2)
#     Line #490 (got 1 columns instead of 2)
#     Line #491 (got 1 columns instead of 2)
#     Line #493 (got 1 columns instead of 2)
#     Line #494 (got 1 columns instead of 2)
#     Line #495 (got 1 columns instead of 2)
#     Line #496 (got 1 columns instead of 2)
#     Line #497 (got 1 columns instead of 2)
#     Line #498 (got 1 columns instead of 2)
#     Line #499 (got 1 columns instead of 2)
#     Line #500 (got 1 columns instead of 2)
#     Line #501 (got 1 columns instead of 2)
#     Line #503 (got 1 columns instead of 2)
#     Line #504 (got 1 columns instead of 2)
#     Line #505 (got 1 columns instead of 2)
#     Line #506 (got 1 columns instead of 2)
#     Line #507 (got 1 columns instead of 2)
#     Line #508 (got 1 columns instead of 2)
#     Line #512 (got 1 columns instead of 2)
#     Line #513 (got 1 columns instead of 2)
#     Line #514 (got 1 columns instead of 2)
#     Line #515 (got 1 columns instead of 2)
#     Line #516 (got 1 columns instead of 2)
#     Line #517 (got 1 columns instead of 2)
#     Line #519 (got 1 columns instead of 2)
#     Line #520 (got 1 columns instead of 2)
#     Line #521 (got 1 columns instead of 2)
#     Line #522 (got 1 columns instead of 2)
#     Line #523 (got 1 columns instead of 2)
#     Line #524 (got 1 columns instead of 2)
#     Line #525 (got 1 columns instead of 2)
#     Line #526 (got 1 columns instead of 2)
#     Line #527 (got 1 columns instead of 2)
#     Line #528 (got 1 columns instead of 2)
#     Line #529 (got 1 columns instead of 2)
#     Line #530 (got 1 columns instead of 2)
#     Line #531 (got 1 columns instead of 2)
#     Line #532 (got 1 columns instead of 2)
#     Line #533 (got 1 columns instead of 2)
#     Line #534 (got 1 columns instead of 2)
#     Line #535 (got 1 columns instead of 2)
#     Line #536 (got 1 columns instead of 2)
#     Line #537 (got 1 columns instead of 2)
#     Line #538 (got 1 columns instead of 2)
#     Line #539 (got 1 columns instead of 2)
#     Line #540 (got 1 columns instead of 2)
#     Line #541 (got 1 columns instead of 2)
#     Line #542 (got 1 columns instead of 2)
#     Line #543 (got 1 columns instead of 2)
#     Line #544 (got 1 columns instead of 2)
#     Line #545 (got 1 columns instead of 2)
#     Line #546 (got 1 columns instead of 2)
#     Line #547 (got 1 columns instead of 2)
#     Line #548 (got 1 columns instead of 2)
#     Line #549 (got 1 columns instead of 2)
#     Line #550 (got 1 columns instead of 2)
#     Line #551 (got 1 columns instead of 2)
#     Line #552 (got 1 columns instead of 2)
#     Line #553 (got 1 columns instead of 2)
#     Line #554 (got 1 columns instead of 2)
#     Line #555 (got 1 columns instead of 2)
#     Line #556 (got 1 columns instead of 2)
#     Line #557 (got 1 columns instead of 2)
#     Line #558 (got 1 columns instead of 2)
#     Line #559 (got 1 columns instead of 2)
#     Line #560 (got 1 columns instead of 2)
#     Line #561 (got 1 columns instead of 2)
#     Line #562 (got 1 columns instead of 2)
#     Line #563 (got 1 columns instead of 2)
#     Line #564 (got 1 columns instead of 2)
#     Line #565 (got 1 columns instead of 2)
#     Line #566 (got 1 columns instead of 2)
#     Line #567 (got 1 columns instead of 2)
#     Line #568 (got 1 columns instead of 2)
#     Line #569 (got 1 columns instead of 2)
#     Line #570 (got 1 columns instead of 2)
#     Line #571 (got 1 columns instead of 2)
#     Line #572 (got 1 columns instead of 2)
#     Line #573 (got 1 columns instead of 2)
#     Line #574 (got 1 columns instead of 2)
#     Line #575 (got 1 columns instead of 2)
#     Line #576 (got 1 columns instead of 2)
#     Line #577 (got 1 columns instead of 2)
#     Line #578 (got 1 columns instead of 2)
#     Line #579 (got 1 columns instead of 2)
#     Line #580 (got 1 columns instead of 2)
#     Line #581 (got 1 columns instead of 2)
#     Line #582 (got 1 columns instead of 2)
#     Line #583 (got 1 columns instead of 2)
#     Line #584 (got 1 columns instead of 2)
#     Line #585 (got 1 columns instead of 2)
#     Line #586 (got 1 columns instead of 2)
#     Line #587 (got 1 columns instead of 2)
#     Line #588 (got 1 columns instead of 2)
#     Line #589 (got 1 columns instead of 2)
#     Line #590 (got 1 columns instead of 2)
#     Line #591 (got 1 columns instead of 2)
#     Line #592 (got 1 columns instead of 2)
#     Line #593 (got 1 columns instead of 2)
#     Line #594 (got 1 columns instead of 2)
#     Line #595 (got 1 columns instead of 2)
#     Line #596 (got 1 columns instead of 2)
#     Line #597 (got 1 columns instead of 2)
#     Line #598 (got 1 columns instead of 2)
#     Line #599 (got 1 columns instead of 2)
#     Line #600 (got 1 columns instead of 2)
#     Line #601 (got 1 columns instead of 2)
#     Line #602 (got 1 columns instead of 2)
#     Line #603 (got 1 columns instead of 2)
#     Line #604 (got 1 columns instead of 2)
#     Line #605 (got 1 columns instead of 2)
#     Line #606 (got 1 columns instead of 2)
#     Line #607 (got 1 columns instead of 2)
#     Line #608 (got 1 columns instead of 2)
#     Line #609 (got 1 columns instead of 2)
#     Line #610 (got 1 columns instead of 2)
#     Line #611 (got 1 columns instead of 2)
#     Line #612 (got 1 columns instead of 2)
#     Line #613 (got 1 columns instead of 2)
#     Line #614 (got 1 columns instead of 2)
#     Line #615 (got 1 columns instead of 2)
#     Line #616 (got 1 columns instead of 2)
#     Line #617 (got 1 columns instead of 2)
#     Line #618 (got 1 columns instead of 2)
#     Line #619 (got 1 columns instead of 2)
#     Line #620 (got 1 columns instead of 2)
#     Line #621 (got 1 columns instead of 2)
#     Line #622 (got 1 columns instead of 2)
#     Line #623 (got 1 columns instead of 2)
#     Line #624 (got 1 columns instead of 2)
#     Line #625 (got 1 columns instead of 2)
#     Line #626 (got 1 columns instead of 2)
#     Line #627 (got 1 columns instead of 2)
#     Line #628 (got 1 columns instead of 2)
#     Line #629 (got 1 columns instead of 2)
#     Line #630 (got 1 columns instead of 2)
#     Line #631 (got 1 columns instead of 2)
#     Line #632 (got 1 columns instead of 2)
#     Line #633 (got 1 columns instead of 2)
#     Line #634 (got 1 columns instead of 2)
#     Line #635 (got 1 columns instead of 2)
#     Line #636 (got 1 columns instead of 2)
#     Line #637 (got 1 columns instead of 2)
#     Line #638 (got 1 columns instead of 2)
#     Line #639 (got 1 columns instead of 2)
#     Line #640 (got 1 columns instead of 2)
#     Line #641 (got 1 columns instead of 2)
#     Line #642 (got 1 columns instead of 2)
#     Line #643 (got 1 columns instead of 2)
#     Line #644 (got 1 columns instead of 2)
#     Line #645 (got 1 columns instead of 2)
#     Line #646 (got 1 columns instead of 2)
#     Line #647 (got 1 columns instead of 2)
#     Line #648 (got 1 columns instead of 2)
#     Line #649 (got 1 columns instead of 2)
#     Line #650 (got 1 columns instead of 2)
#     Line #651 (got 1 columns instead of 2)
#     Line #652 (got 1 columns instead of 2)
#     Line #653 (got 1 columns instead of 2)
#     Line #654 (got 1 columns instead of 2)
#     Line #655 (got 1 columns instead of 2)
#     Line #656 (got 1 columns instead of 2)
#     Line #657 (got 1 columns instead of 2)
#     Line #658 (got 1 columns instead of 2)
#     Line #659 (got 1 columns instead of 2)
#     Line #660 (got 1 columns instead of 2)
#     Line #661 (got 1 columns instead of 2)
#     Line #662 (got 1 columns instead of 2)
#     Line #663 (got 1 columns instead of 2)
#     Line #664 (got 1 columns instead of 2)
#     Line #665 (got 1 columns instead of 2)
#     Line #666 (got 1 columns instead of 2)
#     Line #667 (got 1 columns instead of 2)
#     Line #668 (got 1 columns instead of 2)
#     Line #669 (got 1 columns instead of 2)
#     Line #670 (got 1 columns instead of 2)
#     Line #671 (got 1 columns instead of 2)
#     Line #672 (got 1 columns instead of 2)
#     Line #673 (got 1 columns instead of 2)
#     Line #674 (got 1 columns instead of 2)
#     Line #675 (got 1 columns instead of 2)
#     Line #676 (got 1 columns instead of 2)
#     Line #677 (got 1 columns instead of 2)
#     Line #678 (got 1 columns instead of 2)
#     Line #679 (got 1 columns instead of 2)
#     Line #680 (got 1 columns instead of 2)
#     Line #681 (got 1 columns instead of 2)
#     Line #682 (got 1 columns instead of 2)
#     Line #683 (got 1 columns instead of 2)
#     Line #684 (got 1 columns instead of 2)
#     Line #686 (got 1 columns instead of 2)
#     Line #688 (got 1 columns instead of 2)
#     Line #690 (got 1 columns instead of 2)
#     Line #691 (got 1 columns instead of 2)
#     Line #692 (got 1 columns instead of 2)
#     Line #693 (got 1 columns instead of 2)
#     Line #694 (got 1 columns instead of 2)
#     Line #695 (got 1 columns instead of 2)
#     Line #698 (got 1 columns instead of 2)
#     Line #699 (got 1 columns instead of 2)
#     Line #700 (got 1 columns instead of 2)
#     Line #702 (got 1 columns instead of 2)
#     Line #703 (got 1 columns instead of 2)
#     Line #705 (got 1 columns instead of 2)
#     Line #708 (got 1 columns instead of 2)
#     Line #709 (got 1 columns instead of 2)
#     Line #710 (got 1 columns instead of 2)
#     Line #711 (got 2 columns instead of 2)
#     Line #717 (got 1 columns instead of 2)
#     Line #719 (got 1 columns instead of 2)
#     Line #720 (got 1 columns instead of 2)
#     Line #721 (got 1 columns instead of 2)
#     Line #722 (got 1 columns instead of 2)
#     Line #730 (got 1 columns instead of 2)
#     Line #731 (got 1 columns instead of 2)
#     Line #732 (got 1 columns instead of 2)
#     Line #736 (got 1 columns instead of 2)
#     Line #737 (got 1 columns instead of 2)
#     Line #738 (got 1 columns instead of 2)
#     Line #739 (got 1 columns instead of 2)
#     Line #740 (got 1 columns instead of 2)
#     Line #741 (got 1 columns instead of 2)
#     Line #742 (got 1 columns instead of 2)
#     Line #745 (got 1 columns instead of 2)
#     Line #746 (got 1 columns instead of 2)
#     Line #747 (got 1 columns instead of 2)
#     Line #748 (got 1 columns instead of 2)
#     Line #749 (got 1 columns instead of 2)
#     Line #750 (got 1 columns instead of 2)
#     Line #751 (got 1 columns instead of 2)
#     Line #752 (got 1 columns instead of 2)
#     Line #753 (got 1 columns instead of 2)
#     Line #754 (got 1 columns instead of 2)
#     Line #755 (got 1 columns instead of 2)
#     Line #756 (got 1 columns instead of 2)
#     Line #757 (got 1 columns instead of 2)
#     Line #758 (got 1 columns instead of 2)
#     Line #759 (got 1 columns instead of 2)
#     Line #763 (got 1 columns instead of 2)
#     Line #764 (got 1 columns instead of 2)
#     Line #767 (got 1 columns instead of 2)

# %%
plt.scatter(challenger_data[:, 0], challenger_data[:, 1], s=75, color="k",
            alpha=0.5)
plt.yticks([0, 1])
plt.ylabel("Damage Incident?")
plt.xlabel("Outside temperature (Fahrenheit)")
plt.title("Defects of the Space Shuttle O-Rings vs temperature");

# %%
temperature = challenger_data[:, 0]
D = challenger_data[:, 1]

# %%
alpha = pm.Normal('alpha', 0, 0.0001, value=0)

# %%
beta = pm.Normal('beta', 0, 0.0001, value=0)

# %%
@pm.deterministic
def p(t=temperature, a=alpha, b=beta):
    return 1.0 / (1 + np.exp(b * t + a))

# %%
accident = pm.Bernoulli('bernoulli_obs', p, value=D, observed=True)

# %%
model = pm.Model([alpha, beta, accident])
map_ = pm.MAP(model)
map_.fit()
mcmc = pm.MCMC(model)
mcmc.sample(120000, 100000, 2)
# Out:
#  [-----------------100%-----------------] 120000 of 120000 complete in 10.5 sec

# %%
alpha_samples = mcmc.trace('alpha')[:, None]
beta_samples = mcmc.trace('beta')[:, None]

# %%
figsize(12.5, 6)

# histogram of the samples:
plt.subplot(211)
plt.title(r"Posterior distributions of the variables $\alpha, \beta$")
plt.hist(beta_samples, histtype='stepfilled', bins=35, alpha=0.85,
         label=r"posterior of $\beta$", color="#7A68A6", normed=True)
plt.legend()

plt.subplot(212)
plt.hist(alpha_samples, histtype='stepfilled', bins=35, alpha=0.85,
         label=r"posterior of $\alpha$", color="#A60628", normed=True)
plt.legend();

# %%
t = np.linspace(temperature.min() - 5, temperature.max() + 5, 50)[:, None]

# %%
p_t = logistic(t.T, beta_samples, alpha_samples)

# %%
mean_prob_t = p_t.mean(axis=0)

# %%
figsize(12.5, 4)

plt.plot(t, mean_prob_t, lw=3, label="average posterior \nprobability \
of defect")
plt.plot(t, p_t[0, :], ls="--", label="realization from posterior")
plt.plot(t, p_t[-100, :], ls="--", label="realization from posterior")
plt.plot(t, p_t[-1000, :], ls="--", label="realization from posterior")
plt.scatter(temperature, D, color="k", s=50, alpha=0.5)
plt.title("Posterior expected value of probability of defect; \
plus realizations")
plt.legend(loc="lower left")
plt.ylim(-0.1, 1.1)
plt.xlim(t.min(), t.max())
plt.ylabel("probability")
plt.xlabel("temperature");

# %%
from scipy.stats.mstats import mquantiles
qs = mquantiles(p_t, [0.025, 0.975], axis=0)

plt.fill_between(t[:, 0], *qs, alpha=0.7,
                 color="#7A68A6")

plt.plot(t[:, 0], qs[0], label="95% CI", color="#7A68A6", alpha=0.7)

plt.plot(t, mean_prob_t, lw=1, ls="--", color="k",
         label="average posterior \nprobability of defect")

plt.xlim(t.min(), t.max())
plt.ylim(-0.02, 1.02)
plt.legend(loc="lower left")
plt.scatter(temperature, D, color="k", s=50, alpha=0.5)
plt.xlabel("temp, $t$")

plt.ylabel("probability estimate")
plt.title("Posterior probability estimates given temp. $t$");

# %%
prob_31 = logistic(31, beta_samples, alpha_samples)

# %%
plt.xlim(0.995, 1)
plt.hist(prob_31, bins=100, normed=True, histtype='stepfilled')
plt.title("Posterior distribution of probability of defect, given $t = 31$")
plt.xlabel("probability of defect occurring in O-ring");

# %% [markdown]
# ---
# * simulate

# %%
simulated = pm.Bernoulli('bernoulli_sim', p)
N = 10000

mcmc = pm.MCMC([simulated, alpha, beta, accident])
mcmc.sample(N)
# Out:
#  [-----------------100%-----------------] 10000 of 10000 complete in 1.9 sec

# %%
figsize(12.5, 5)
simulations = mcmc.trace('bernoulli_sim')[:]
simulations.shape
# Out:
# (10000, 23)

# %%
for i in range(4):
    ax = plt.subplot(4, 1, i + 1)
    plt.scatter(temperature, simulations[1000 * i, :], color="k", s=50, alpha=0.6)

# %%
# 后验概率
posterior_probability = simulations.mean(axis=0)
print("posterior prob of defect | realized defect ")
for i in range(len(D)):
    print("%.2f                     |   %d" % (posterior_probability[i], D[i]))
# Out:
# posterior prob of defect | realized defect
# 0.49                     |   0
# 0.26                     |   1
# 0.30                     |   0
# 0.36                     |   0
# 0.42                     |   0
# 0.17                     |   0
# 0.13                     |   0
# 0.26                     |   0
# 0.91                     |   1
# 0.67                     |   1
# 0.26                     |   1
# 0.04                     |   0
# 0.42                     |   0
# 0.96                     |   1
# 0.43                     |   0
# 0.09                     |   0
# 0.25                     |   0
# 0.02                     |   0
# 0.07                     |   0
# 0.03                     |   0
# 0.09                     |   1
# 0.07                     |   0
# 0.87                     |   1

# %%
# 风骚排序小技巧
ix = np.argsort(posterior_probability)
print("posterior prob of defect | realized defect ")
for i in range(len(D)):
    print("%.2f                     |   %d" % (posterior_probability[ix[i]], D[ix[i]]))
# Out:
# posterior prob of defect | realized defect
# 0.02                     |   0
# 0.03                     |   0
# 0.04                     |   0
# 0.07                     |   0
# 0.07                     |   0
# 0.09                     |   1
# 0.09                     |   0
# 0.13                     |   0
# 0.17                     |   0
# 0.25                     |   0
# 0.26                     |   0
# 0.26                     |   1
# 0.26                     |   1
# 0.30                     |   0
# 0.36                     |   0
# 0.42                     |   0
# 0.42                     |   0
# 0.43                     |   0
# 0.49                     |   0
# 0.67                     |   1
# 0.87                     |   1
# 0.91                     |   1
# 0.96                     |   1

# %%
import separation_plot 
reload(separation_plot)
figsize(11., 1.5)
separation_plot.separation_plot(posterior_probability, D)
